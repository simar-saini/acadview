# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#replacing the age with mean 


from sklearn.preprocessing import Imputer
age_imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
age_imputer = age_imputer.fit(df.iloc[ : , [5]])
df.iloc[:, [5]] = age_imputer.transform(df.iloc[:, [5]])
df.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#       Sex  Age  SibSp  Parch            Ticket     Fare Cabin  Pclass_1  \
# 0    male   28    1.0      0         A/5 21171   7.2500   NaN         0
# 1  female   52    1.0      0          PC 17599  71.2833   C85         1
# 2  female   34    0.0      0  STON/O2. 3101282   7.9250   NaN         0
# 3  female   48    1.0      0            113803  53.1000  C123         1
# 4    male   48    0.0      0            373450   8.0500   NaN         0
#
#    Pclass_2  Pclass_3  Embarked_0  Embarked_1  Embarked_2
# 0         0         1           0           0           1
# 1         0         0           1           0           0
# 2         0         1           0           0           1
# 3         0         0           0           0           1
# 4         0         1           0           0           1

# %%
#age fixed with mean
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Embarked value is checked
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#replacing the embarked value with Maximum number of Category
#i.e., S

df['Embarked'] = df['Embarked'].fillna('S')
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#Embarked and Pclass using one-hot encoding
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_sex = LabelEncoder()
df.iloc[:, [4]] = labelencoder_sex.fit_transform(df.iloc[:, [4]])
df.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#       Sex  Age  SibSp  Parch            Ticket     Fare Cabin  Pclass_1  \
# 0    male   28      1      0         A/5 21171   7.2500   NaN         0
# 1  female   52      1      0          PC 17599  71.2833   C85         1
# 2  female   34      0      0  STON/O2. 3101282   7.9250   NaN         0
# 3  female   48      1      0            113803  53.1000  C123         1
# 4    male   48      0      0            373450   8.0500   NaN         0
#
#    Pclass_2  Pclass_3  Embarked_0  Embarked_1  Embarked_2
# 0         0         1           0           0           1
# 1         0         0           1           0           0
# 2         0         1           0           0           1
# 3         0         0           0           0           1
# 4         0         1           0           0           1

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_embarked = LabelEncoder()
df.iloc[:, [11]] = labelencoder_embarked.fit_transform(df.iloc[:, [11]])
df.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#       Sex  Age  SibSp  Parch            Ticket     Fare Cabin  Pclass_1  \
# 0    male   28      1      0         A/5 21171   7.2500   NaN         0
# 1  female   52      1      0          PC 17599  71.2833   C85         1
# 2  female   34      0      0  STON/O2. 3101282   7.9250   NaN         0
# 3  female   48      1      0            113803  53.1000  C123         1
# 4    male   48      0      0            373450   8.0500   NaN         0
#
#    Pclass_2  Pclass_3  Embarked_0  Embarked_1  Embarked_2
# 0         0         1           0           0           1
# 1         0         0           1           0           0
# 2         0         1           0           0           1
# 3         0         0           0           0           1
# 4         0         1           0           0           1

# %%
df=pd.get_dummies(df,columns=['Pclass','Embarked'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-a1b1e63c4572> in <module>()
# ----> 1 df=pd.get_dummies(df,columns=['Pclass','Embarked'])
#       2 df.head()
#
# c:\python27\lib\site-packages\pandas\core\reshape\reshape.pyc in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first)
#    1202             with_dummies = []
#    1203         else:
# -> 1204             with_dummies = [data.drop(columns_to_encode, axis=1)]
#    1205
#    1206         for (col, pre, sep) in zip(columns_to_encode, prefix, prefix_sep):
#
# c:\python27\lib\site-packages\pandas\core\generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# c:\python27\lib\site-packages\pandas\core\generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# c:\python27\lib\site-packages\pandas\core\indexes\base.pyc in drop(self, labels, errors)
#    3739             if errors != 'ignore':
#    3740                 raise ValueError('labels %s not contained in axis' %
# -> 3741                                  labels[mask])
#    3742             indexer = indexer[~mask]
#    3743         return self.delete(indexer)
#
# ValueError: labels ['Pclass' 'Embarked'] not contained in axis
